# %% [markdown]
# # **The Impact of Crime on Employment and Economic Growth in Los Angeles**

# %% [markdown]
# **Group A6**

# %% [markdown]
# *   Allison Kramer
# *   Adam Schuler
#
# *   Alex Jiang
# *   Drishti Chulani (Project Manager)
#
#
# *   Quency Ye

# %% [markdown]
# ## **Introduction & Motivation**

# %% [markdown]
# Crime is one of the most persistent challenges facing large urban areas, and Los Angeles is no exception. Beyond its direct impact on public safety, crime influences how communities grow, how businesses operate, and how residents experience their daily lives. At the same time, employment opportunities are a cornerstone of economic stability and well-being. Understanding how these two forces interact can provide valuable insights for both policymakers and community leaders.
#
# This project aims to shine light on those connections by exploring how patterns of crime and labor market trends intersect in Los Angeles. By analyzing decades of data, we hope to uncover whether certain shifts in employment conditions align with changes in crime dynamics. Our motivation is not only academic but also practical: highlighting these relationships may inform strategies that improve safety, strengthen the economy, and enhance the overall quality of life for residents across the city.

# %% [markdown]
# ## **1. Business Problem Definition**

# %% [markdown]
# ### **1.1 Problem Statement**
#
# Crime significantly impacts the social and economic well-being of Los Angeles, a diverse city with a dynamic economy. Understanding crime patterns is critical not only for improving public safety but also for supporting long-term economic growth and employment. To explore this relationship, we analyzed crime records from the Los Angeles Police Department alongside labor market data for Los Angeles County from 1990 to 2025. Our goal is to identify trends in crime and employment to highlight strategies that enhance safety and expand job opportunities in the city.

# %% [markdown]
# **Data Sources**
#
# 1. Crime Data from 2020 to present: https://catalog.data.gov/dataset/crime-data-from-2020-to-present
#
# 2. Crime Data from 2010 to 2019: https://catalog.data.gov/dataset/crime-data-from-2010-to-2019
#
# 3. Employment and unemployment from 1990 to 2025: https://labormarketinfo.edd.ca.gov/geography/losangeles-county.html

# %% [markdown]
# ### **1.2 Description**

# %% [markdown]
# Los Angeles faces persistent challenges with crime, which affects both community safety and the city’s economic vitality. To better understand this relationship, our study brings together two large datasets: crime records from the Los Angeles Police Department and labor market data for Los Angeles County from 1990–2025. The crime dataset contains millions of reported incidents, providing detailed information on location, time of day, and victim demographics, while the labor dataset captures long-term trends in employment, unemployment, and labor force participation.
#
# Our first step involved extensive data cleaning and preparation to create tidy datasets suitable for analysis. This included handling missing values, standardizing formats, and ensuring consistency across years of reporting. We then generated a series of visualizations to simplify complex information, making it easier to identify patterns across neighborhoods, times of day, and demographic groups. For example, we examined crime density over the years across different neighborhoods, analyzed unemployment rate seasonality in recent years, and explored how the number of crimes varies by hour of the day.
#
# To connect these insights to the economic dimension, we analyzed employment data to highlight annual trends in job growth and unemployment rates, and compared them against shifts in crime levels over the same period. Our approach allows us to investigate whether fluctuations in public safety may be linked to broader labor market conditions. By combining statistical analysis with clear visual storytelling, this study provides an accessible view of how crime and employment trends intersect in Los Angeles.
#
# Ultimately, the description of patterns across crime and employment not only informs public understanding but also offers a foundation for evidence-based strategies aimed at improving safety and supporting sustainable economic growth.

# %% [markdown]
# ## **2.Executive Summary**

# %% [markdown]
# This project investigates the relationship between crime patterns and employment trends in Los Angeles to identify when and where crimes occur most frequently, how they vary by victim demographics, and how shifts in unemployment may relate to these trends. Using cleaned and standardized multi-year datasets from the LAPD and Los Angeles County labor records, we conducted exploratory data analysis to uncover key temporal, spatial, and demographic patterns.
#
# Our findings reveal that crime peaks around midday and evening hours, with Central and Downtown LA consistently emerging as high density areas. Vehicle theft surged in 2022 before easing in 2023, while identity theft also saw a sharp rise during that period. Men were more often victims of violent and street crimes, whereas women were disproportionately affected by domestic violence and identity related offenses. Hispanic victims represented the largest share of recorded cases, reflecting demographic disparities in victimization.
#
# While unemployment followed a seasonal cycle rising midsummer and falling toward year end it showed limited overall correlation with crime rates. However, certain offenses, such as purse snatching and child neglect, rose slightly during higher unemployment periods, suggesting that economic conditions may indirectly influence specific crimes.
#
# Based on these insights, we recommend targeted law enforcement during peak activity hours, community education around domestic and identity crimes, and workforce programs that support economic stability. These strategies provide a foundation for data driven policymaking to enhance safety and resilience across Los Angeles.

# %% [markdown]
# ## **3. Data Overview**

# %% [markdown]
# ### **3.1 Overview**

# %% [markdown]
# This project draws on two main sources of data related to crime and employment in Los Angeles.
#
# The first source is crime records provided by the City of Los Angeles through Data.gov. We used two datasets: Crime Data from 2020 to present and Crime Data from 2010 to 2019. Together, these datasets contain millions of reported crime incidents across Los Angeles over the past 15 years. Some key attributes include:
#
#
# *   Crime Type and Description: General classification of the crime (e.g., theft, assault, burglary) and more detailed incident descriptions.
# *   Location: Information on where the crime occurred, including street address, area, and geographic codes useful for neighborhood-level analysis.
# *   Date and Time: The exact date and time of the reported crime, enabling temporal analysis across years, months, and hours of the day.
# *   Victim Demographics: Gender, age, and descent of victims, which allow for analysis of how crime affects different groups.
# *   Case Information: Details such as whether an arrest was made and unique crime report IDs for tracking and deduplication.
#
#
# The second source is labor market data from the California Employment Development Department (EDD), covering Los Angeles County from 1990 to 2025: Employment and unemployment from 1990 to 2025. This dataset provides long-term trends in the county’s labor force and employment conditions. Some key attributes include:
#
# *   Employment Levels: Total number of employed individuals by year.
# *   Unemployment Levels: Annual unemployment counts and unemployment rates.
# *   Labor Force Size: Overall size of the labor force, enabling comparisons of employment fluctuations relative to population.
# *   Trends Over Time: Historical and projected data, making it possible to analyze seasonality, long-term shifts, and potential links to social factors like crime.
#
# By combining these two sources, we were able to explore how patterns of crime intersect with changes in employment and unemployment across Los Angeles.

# %% [markdown]
# ### **3.2 Data Dictionary**

# %% [markdown]
# Crime Dataset
#
# | **Column**          | **Description**                                                                 |
# | :------------------ | :------------------------------------------------------------------------------ |
# | **DR_NO**           | Official report number, composed of a 2-digit year, area ID, and 5-digit sequence. |
# | **Date Rptd**       | Date the crime was reported to the police. |
# | **DATE OCC**        | Date the crime occurred. |
# | **TIME OCC**        | Time of occurrence in 24-hour format (range: **0001–2359**). |
# | **AREA NAME**       | Name of one of the **21** LAPD geographic areas (each corresponding to a community police station). |
# | **AREA**            | Numeric ID of the area (range: **1–21**). |
# | **Rpt Dist No**     | Four-digit reporting district code identifying sub-areas within each geographic area (range: **101–2199**). |
# | **Part 1–2**        | Indicates whether the offense is classified as **Part I** or **Part II** under the FBI’s Uniform Crime Reporting system. |
# | **Crm Cd**          | Primary crime code. |
# | **Crm Cd Desc**     | Description of the crime (e.g., *Vehicle – Stolen*, *Burglary from Vehicle*). |
# | **Vict Age**        | Victim’s age (range: **–4 to 120** years). Negative values may represent data errors or special codes. |
# | **Vict Sex**        | Victim’s gender. |
# | **Premis Cd**       | Code representing the type of location where the incident occurred (e.g., residence, street, business). |
# | **Status Desc**     | Description of the report or investigation status. |
# | **Weapon Used Cd**  | Code indicating the weapon used (if any). Only about **10 %** of cases specify a weapon; mean code value ≈ **362.6**. |
# | **Latitude (LAT)**  | Geographic latitude of the incident. |
# | **Longitude (LON)** | Geographic longitude of the incident. |

# %% [markdown]
# Employment Dataset
#
# | **Column**       | **Description**                                                                       |
# | :--------------- | :------------------------------------------------------------------------------------ |
# | **ym**           | Year and month of observation in **YYYY-MM** format.                                  |
# | **Labor Force**  | Total number of individuals participating in the labor force (employed + unemployed). |
# | **Employment**   | Total number of employed individuals.                                                 |
# | **Unemployment** | Total number of unemployed individuals.                                               |
# | **Unemp. Rate**  | Unemployment rate — ratio of unemployed to total labor force.                         |

# %% [markdown]
# ### 3.3 Importing Tools Needed

# %%
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Section 1: Importing our Google Drive to Access Our Data

# %%
#Drishtis Computer Run
LA_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/780 project/1990-2025 employment & unemployment.csv')
LA_crime1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/780 project/Crime_Data_from_2020_to_Present.csv')
LA_crime2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/780 project/Crime_Data_from_2010_to_2019.csv')

# %%
# # #Allisons Computer Run
# LA_data = pd.read_csv('/content/drive/MyDrive/MSBA Fall 2025/Intro-to-Data-Analytics/Data Group Project/1990-2025 employment & unemployment (1).csv')
# LA_crime1 = pd.read_csv('/content/drive/MyDrive/MSBA Fall 2025/Intro-to-Data-Analytics/Data Group Project/Copy of Crime_Data_from_2020_to_Present.csv')
# LA_crime2 = pd.read_csv('/content/drive/MyDrive/MSBA Fall 2025/Intro-to-Data-Analytics/Data Group Project/Copy of Crime_Data_from_2010_to_2019.csv')

# %%
# # Quencys Laptop Run
LA_data = pd.read_csv('/content/drive/MyDrive/780_Project/Shared Folder/Original_1990-2025 employment & unemployment.csv')
LA_crime1 = pd.read_csv('/content/drive/MyDrive/780_Project/Shared Folder/Crime_Data_from_2020_to_Present.csv')
LA_crime2 = pd.read_csv('/content/drive/MyDrive/780_Project/Shared Folder/Crime_Data_from_2010_to_2019.csv')

# %%
#Alex Run
# LA_data = pd.read_csv('/content/drive/MyDrive/BA 780 Materials/Crime project/1990-2025 employment & unemployment.CSV')
# LA_crime1 = pd.read_csv('/content/drive/MyDrive/BA 780 Materials/Crime project/Copy of Crime_Data_from_2010_to_2019.csv')
# LA_crime2 = pd.read_csv('/content/drive/MyDrive/BA 780 Materials/Crime project/Copy of Crime_Data_from_2020_to_Present.csv')

# %% [markdown]
# ## Section 2: Getting Familiar With Our Data

# %%
LA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553 entries, 0 to 552
# Data columns (total 5 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   September 19, 2025                 514 non-null    object
#  1   Unnamed: 1                         499 non-null    object
#  2   Employment Development Department  501 non-null    object
#  3   Unnamed: 3                         499 non-null    object
#  4   Unnamed: 4                         499 non-null    object
# dtypes: object(5)
# memory usage: 21.7+ KB

# %%
LA_crime2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2133137 entries, 0 to 2133136
# Data columns (total 28 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       object
#  2   DATE OCC        object
#  3   TIME OCC        int64
#  4   AREA            int64
#  5   AREA NAME       object
#  6   Rpt Dist No     int64
#  7   Part 1-2        int64
#  8   Crm Cd          int64
#  9   Crm Cd Desc     object
#  10  Mocodes         object
#  11  Vict Age        int64
#  12  Vict Sex        object
#  13  Vict Descent    object
#  14  Premis Cd       float64
#  15  Premis Desc     object
#  16  Weapon Used Cd  float64
#  17  Weapon Desc     object
#  18  Status          object
#  19  Status Desc     object
#  20  Crm Cd 1        float64
#  21  Crm Cd 2        float64
#  22  Crm Cd 3        float64
#  23  Crm Cd 4        float64
#  24  LOCATION        object
#  25  Cross Street    object
#  26  LAT             float64
# ...

# %%
LA_crime1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004991 entries, 0 to 1004990
# Data columns (total 28 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   DR_NO           1004991 non-null  int64
#  1   Date Rptd       1004991 non-null  object
#  2   DATE OCC        1004991 non-null  object
#  3   TIME OCC        1004991 non-null  int64
#  4   AREA            1004991 non-null  int64
#  5   AREA NAME       1004991 non-null  object
#  6   Rpt Dist No     1004991 non-null  int64
#  7   Part 1-2        1004991 non-null  int64
#  8   Crm Cd          1004991 non-null  int64
#  9   Crm Cd Desc     1004991 non-null  object
#  10  Mocodes         853372 non-null   object
#  11  Vict Age        1004991 non-null  int64
#  12  Vict Sex        860347 non-null   object
#  13  Vict Descent    860335 non-null   object
#  14  Premis Cd       1004975 non-null  float64
#  15  Premis Desc     1004403 non-null  object
# ...

# %%
# To Find the Shape:

LA_crime1.shape
LA_crime2.shape

print("Crime 1 Data Set:", LA_crime1.shape)
print("Crime 2 Data Set: ", LA_crime2.shape)
# Out:
# Crime 1 Data Set: (1004991, 28)
# Crime 2 Data Set:  (2133137, 28)

# %%
# Clean Column Names:

LA_crime1.rename(columns=lambda x: x.strip(), inplace=True)
LA_crime2.rename(columns=lambda x: x.strip(), inplace=True)

# %%
# Union of LA_crime1 and LA_crime2:

T_crime= pd.concat([LA_crime1, LA_crime2], ignore_index=True)
T_crime.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  211507896  04/11/2021 12:00:00 AM  11/07/2020 12:00:00 AM       845    15
# 1  201516622  10/21/2020 12:00:00 AM  10/18/2020 12:00:00 AM      1845    15
# 2  240913563  12/10/2024 12:00:00 AM  10/30/2020 12:00:00 AM      1240     9
# 3  210704711  12/24/2020 12:00:00 AM  12/24/2020 12:00:00 AM      1310     7
# 4  201418201  10/03/2020 12:00:00 AM  09/29/2020 12:00:00 AM      1830    14
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  N Hollywood         1502         2     354
# 1  N Hollywood         1521         1     230
# 2     Van Nuys          933         2     354
# 3     Wilshire          782         1     331
# 4      Pacific         1454         1     420
#
#                                          Crm Cd Desc  ... Status  Status Desc  \
# 0                                  THEFT OF IDENTITY  ...     IC  Invest Cont
# ...

# %%
# T_crime Information:

print(T_crime.shape)
print(T_crime.info())
# Out:
# (3138128, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138128 entries, 0 to 3138127
# Data columns (total 28 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   DR_NO           int64
#  1   Date Rptd       object
#  2   DATE OCC        object
#  3   TIME OCC        int64
#  4   AREA            int64
#  5   AREA NAME       object
#  6   Rpt Dist No     int64
#  7   Part 1-2        int64
#  8   Crm Cd          int64
#  9   Crm Cd Desc     object
#  10  Mocodes         object
#  11  Vict Age        int64
#  12  Vict Sex        object
#  13  Vict Descent    object
#  14  Premis Cd       float64
#  15  Premis Desc     object
#  16  Weapon Used Cd  float64
#  17  Weapon Desc     object
#  18  Status          object
#  19  Status Desc     object
#  20  Crm Cd 1        float64
#  21  Crm Cd 2        float64
#  22  Crm Cd 3        float64
#  23  Crm Cd 4        float64
#  24  LOCATION        object
#  25  Cross Street    object
# ...

# %%
T_crime.isnull().sum()
# Out:
# DR_NO                   0
# Date Rptd               0
# DATE OCC                0
# TIME OCC                0
# AREA                    0
# AREA NAME               0
# Rpt Dist No             0
# Part 1-2                0
# Crm Cd                  0
# Crm Cd Desc             0
# Mocodes            381348
# Vict Age                0
# Vict Sex           342680
# Vict Descent       342739
# Premis Cd              70
# Premis Desc           776
# Weapon Used Cd    2094193
# Weapon Desc       2094194
# Status                  4
# Status Desc             0
# Crm Cd 1               21
# Crm Cd 2          2926937
# Crm Cd 3          3132231
# Crm Cd 4          3137960
# LOCATION                0
# Cross Street      2626799
# LAT                     0
# LON                     0
# dtype: int64

# %% [markdown]
# **Summary:**
#
# In this exploratory phase, we began by reviewing the structure and contents of the 3 datasets using the .info() and .describe() functions to understand data types, distributions, and key statistics for both crime datasets and employment data. We cleaned all the spaces in the crime dataset's headers and concatenated them both. We then checked for missing values using the .isnull().sum() function to identify incomplete records across all columns.
#
# From this inspection, we found that several fields: such as victim age, victim descent, weapon desc, location details; contained alot of missing values or duplicate or inconsistent entries in the Crime dataset. In the employment dataset, the formatting was needed to be cleaned.

# %% [markdown]
# ## Section 3: Data Cleaning

# %% [markdown]
# a) Checking for Duplicate Values

# %%
# 1) Check if T_crime Has Any Duplicates?:

duplicate = T_crime['DR_NO'].duplicated().any()
duplicate_count = T_crime['DR_NO'].duplicated().sum()
print("Are There Any Duplicates? : ", duplicate, "; This is How Many Duplicates There Are: ", duplicate_count)

# 2) Drop duplicate rows based on 'DR_NO' and keep the first occurrence

T_crime_unique= T_crime.drop_duplicates(subset='DR_NO', keep='first')

# 3) To confirm if duplicates are removed:

duplicates = T_crime_unique['DR_NO'].duplicated().sum()
print("The total number of duplicates in new dataset:", duplicates)
# Out:
# Are There Any Duplicates? :  True ; This is How Many Duplicates There Are:  57809
# The total number of duplicates in new dataset: 0

# %% [markdown]
# b) Fixing Inconsistencies in Date Column

# %%
#Data Cleaning for Date Under a Function

import pandas as pd

def clean_date_column(df, colname, dayfirst=True):
    """
    Clean and standardize a date column:
    - Strips spaces
    - Replaces separators with '/'
    - Converts to datetime64[ns]
    - Removes rows with dates in the future
    - Creates Year, Month, Day columns
    """
    # 1. strip and normalize separators
    df[colname] = df[colname].astype(str).str.strip()
    df[colname] = df[colname].str.replace(r'[-.]', '/', regex=True)

    # 2. convert to datetime
    df[colname] = pd.to_datetime(df[colname],
                                 dayfirst=dayfirst,
                                 errors='coerce')

    # 3. remove future dates
    today = pd.Timestamp.today().normalize()
    df = df[df[colname] <= today]

    # 4. add clean string version and parts
    clean_name = f"{colname}_clean"
    df[clean_name] = df[colname].dt.strftime('%m/%d/%Y')
    df[f"{colname}_Year"] = df[colname].dt.year
    df[f"{colname}_Month"] = df[colname].dt.month
    df[f"{colname}_Day"] = df[colname].dt.day
    df[f"{colname}_MonthYear"] = df[colname].dt.to_period('M').astype(str)

    return df

# applying to the table
T_crime_unique = clean_date_column(T_crime_unique, 'Date Rptd', dayfirst=True)
T_crime_unique = clean_date_column(T_crime_unique, 'DATE OCC', dayfirst=True)
# Out:
# /tmp/ipython-input-3463445546.py:29: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-3463445546.py:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-3463445546.py:31: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Quick check
print("Latest 'Date Rptd Clean':", T_crime_unique['Date Rptd_clean'].max())
print("Latest 'DATE OCC Clean':", T_crime_unique['DATE OCC_clean'].max())

print("\nLatest 'Date Rptd':", T_crime_unique['Date Rptd'].max())
print("Latest 'DATE OCC':", T_crime_unique['DATE OCC'].max())

# Sort by 'Date Rptd' descending (latest first) and show top 10
latest_dates = T_crime_unique[['Date Rptd','Date Rptd_clean','DATE OCC','DATE OCC_clean','Date Rptd_MonthYear','DATE OCC_MonthYear']] \
    .sort_values(by='Date Rptd', ascending=False) \
    .head(10)

print("latest dates:", latest_dates)
# Out:
# Latest 'Date Rptd Clean': 12/31/2024
# Latest 'DATE OCC Clean': 12/31/2023
#
# Latest 'Date Rptd': 2025-10-03 00:00:00
# Latest 'DATE OCC': 2025-10-02 00:00:00
# latest dates:          Date Rptd Date Rptd_clean   DATE OCC DATE OCC_clean  \
# 1004967 2025-10-03      10/03/2025 2025-06-03     06/03/2025
# 1004925 2025-10-02      10/02/2025 2025-10-02     10/02/2025
# 877631  2025-10-02      10/02/2025 2023-10-29     10/29/2023
# 1004896 2025-10-02      10/02/2025 2025-06-02     06/02/2025
# 1004966 2025-09-03      09/03/2025 2025-09-03     09/03/2025
# 199830  2025-09-03      09/03/2025 2020-01-09     01/09/2020
# 1004929 2025-09-02      09/02/2025 2025-09-02     09/02/2025
# 1004959 2025-09-02      09/02/2025 2025-09-02     09/02/2025
# 2760683 2025-09-01      09/01/2025 2018-03-22     03/22/2018
# 1004924 2025-08-03      08/03/2025 2025-02-23     02/23/2025
#
#         Date Rptd_MonthYear DATE OCC_MonthYear
# 1004967             2025-10            2025-06
# ...

# %% [markdown]
# c) Changing Time Occurence Format

# %%
# Checking if Time is Between 0 - 2400
invalid_times = T_crime_unique[(T_crime_unique['TIME OCC'] < 0) | (T_crime_unique['TIME OCC'] > 2359)]
print(invalid_times)

# Also Check Formatting Issues (Like 1 Instead of 0001)
T_crime_unique['TIME OCC'] = T_crime_unique['TIME OCC'].astype(str).str.zfill(4)
# Out:
# Empty DataFrame
# Columns: [DR_NO, Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Rpt Dist No, Part 1-2, Crm Cd, Crm Cd Desc, Mocodes, Vict Age, Vict Sex, Vict Descent, Premis Cd, Premis Desc, Weapon Used Cd, Weapon Desc, Status, Status Desc, Crm Cd 1, Crm Cd 2, Crm Cd 3, Crm Cd 4, LOCATION, Cross Street, LAT, LON, Date Rptd_clean, Date Rptd_Year, Date Rptd_Month, Date Rptd_Day, Date Rptd_MonthYear, DATE OCC_clean, DATE OCC_Year, DATE OCC_Month, DATE OCC_Day, DATE OCC_MonthYear]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# d) Making Values Same in Victim Sex & Victim Age

# %%
#What Values Exist:

#Checking for anything weird in Victim Sex (Values other than F or M & Missing Values)
unique_sex = T_crime_unique["Vict Sex"].unique()
print("Unique Values Found in Victim Sex Category: ", unique_sex)

#Checking for anything weird in this category (ex: neg #'s)
descriptive_stats = T_crime_unique["Vict Age"].describe()
min_age = T_crime_unique["Vict Age"].min()
max_age = T_crime_unique["Vict Age"].max()

print("Descriptive Statistics for Victim Age: : ", descriptive_stats)
print("Lowest Victim Age: ", min_age)
print("Highest Victim Age: ", max_age)

# Got familiar with the data and noticed negative values, adjusted accordingly by making min = 0
# There were different values for Victim Sex such as nan, X, H, N, and -
# Out:
# Unique Values Found in Victim Sex Category:  ['M' 'F' nan 'X' 'H' '-' 'N']
# Descriptive Statistics for Victim Age: :  count    3.080288e+06
# mean     3.081246e+01
# std      2.113876e+01
# min     -1.300000e+01
# 25%      1.800000e+01
# 50%      3.100000e+01
# 75%      4.600000e+01
# max      1.200000e+02
# Name: Vict Age, dtype: float64
# Lowest Victim Age:  -13
# Highest Victim Age:  120

# %%
#Cleaning for Victim Sex:

T_crime_unique["Vict Sex"] = T_crime_unique["Vict Sex"].str.upper()

valid_sex = ["M", "F"]

#Set Invalid Values to Nan & set the Invalid Values to Unkown (I used .where from AI)
T_crime_unique["Vict Sex"] = T_crime_unique["Vict Sex"].where(T_crime_unique["Vict Sex"].isin(valid_sex))
T_crime_unique["Vict Sex"] = T_crime_unique["Vict Sex"].fillna("Unknown")

#Checking if it Worked
T_crime_unique["Vict Sex"].value_counts(dropna=False)
# Out:
# Vict Sex
# M          1360240
# F          1230658
# Unknown     489390
# Name: count, dtype: int64

# %%
#Cleaning for Victim Age:

#Make Sure All Values are Numeric First & Set Neg and High Values to Na - Only 0-110 #'s are Valid
T_crime_unique["Vict Age"] = pd.to_numeric(T_crime_unique["Vict Age"], errors = "coerce")


T_crime_unique.loc[T_crime_unique["Vict Age"] < 0, "Vict Age"] = pd.NA
T_crime_unique.loc[T_crime_unique["Vict Age"] > 110, "Vict Age"] = pd.NA

#Put into New DataFrame with only Valid Values & Drop Invalid Values
clean_age = T_crime_unique.dropna(subset = ["Vict Age"]).copy()

#Verify and Printing the Lowest and Highest Victim Age
new_descriptive_stats = clean_age["Vict Age"].describe()
new_min_age = clean_age["Vict Age"].min()
new_max_age = clean_age["Vict Age"].max()

print("New/Cleaned Descriptive Statistics for Victim Age: ", new_descriptive_stats)
print("New/Cleaned Lowest Victim Age: ", new_min_age)
print("New/Cleaned Highest Victim Age: ", new_max_age)
# Out:
# New/Cleaned Descriptive Statistics for Victim Age:  count    1.038512e+06
# mean     3.058912e+01
# std      2.091612e+01
# min      0.000000e+00
# 25%      1.800000e+01
# 50%      3.100000e+01
# 75%      4.500000e+01
# max      9.900000e+01
# Name: Vict Age, dtype: float64
# New/Cleaned Lowest Victim Age:  0.0
# New/Cleaned Highest Victim Age:  99.0

# %%
bins = [0, 20, 40, 60, 80, 100]  # age ranges
labels = ['0-20', '20-40', '40-60', '60-80', '80+']  # labels for bins

# Create a new column for age groups
T_crime_unique['Age Group'] = pd.cut(T_crime_unique['Vict Age'], bins=bins, labels=labels, right=False, include_lowest=True)

# Count number of records in each group
age_group_counts = T_crime_unique['Age Group'].value_counts().sort_index()

print(age_group_counts)
# Out:
# Age Group
# 0-20     279188
# 20-40    409071
# 40-60    261130
# 60-80     80159
# 80+        8964
# Name: count, dtype: int64

# %% [markdown]
# According to the Victim Demographics, Crime predominantly affects younger individuals.
#
# The 20-40 age group has the maximum number of victims, suggesting that they are most at risk and have reported the crime. The median victim age is 31 years.
#
# While 60% of crimes are affecting ages below 40, there is presence of crimes affecting the elderly.*italicized text*
#
# Crime in LA affects both men and women sgnificantly, with male victims slightly more than female victims, which indicates that there is no extreme gender disparity.

# %% [markdown]
# e) Finding Missing & Invalid Values in Area and Area Name

# %%
#Finding Missing/Invalid Variables for Area

#Checking for Unique Values:
unique_area = T_crime_unique["AREA"].unique()
missing_area = T_crime_unique["AREA"].isna().sum()

print("The Unique Values of Area Column: ", unique_area)
print("How Many Missing Values are in the Area Column: ", missing_area)

#Checking for Any Missing Blank Values:
blank_values_area = (T_crime_unique["AREA"] == "").sum()
print("The Amount of Blank Values in Area Column: ", blank_values_area)

total_invalid_area = missing_area + blank_values_area
print("The Total Amount of Invalid Values: ", total_invalid_area)
# Out:
# The Unique Values of Area Column:  [15  9  7 14  4  3 11 17 21  6 20 18 13 16 19  2  1  8 12 10  5]
# How Many Missing Values are in the Area Column:  0
# The Amount of Blank Values in Area Column:  0
# The Total Amount of Invalid Values:  0

# %%
#Finding Missing/Invalid Variables for Area Name

#Removing Potential Unnecessary Spaces:
T_crime_unique["AREA NAME"] = T_crime_unique["AREA NAME"].str.strip()
#Checking That All the Names are Correct:
T_crime_unique["AREA NAME"] = T_crime_unique["AREA NAME"].str.title()

area_counts = T_crime_unique.groupby("AREA NAME").size().sort_values()
print(area_counts)

#Checking for Missing Values:
missing_area_name = T_crime_unique["AREA NAME"].isna().sum()
print("Missing Values in Area Name: ", missing_area_name)

blank_values_area_name = (T_crime_unique["AREA NAME"] == "").sum()
print("Blank Values in Area Name: ", blank_values_area_name)

#Checking for any Weird Values:
weird_chars = T_crime_unique["AREA NAME"].str.contains(r"[^A-Za-z0-9\s.'-]", na=False)
print("These Are Weird Characters: ", weird_chars)
# Out:
# AREA NAME
# Foothill       112968
# Hollenbeck     115034
# Topanga        129436
# West Valley    131678
# Harbor         133357
# Mission        133738
# West La        134562
# Olympic        135934
# Rampart        136447
# Wilshire       136770
# Devonshire     138139
# Van Nuys       142535
# Northeast      143109
# Newton         149238
# Hollywood      151374
# Southeast      151524
# N Hollywood    164873
# Central        167882
# Pacific        171815
# Southwest      192789
# 77Th Street    207086
# dtype: int64
# Missing Values in Area Name:  0
# Blank Values in Area Name:  0
# These Are Weird Characters:  0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 3138123    False
# 3138124    False
# 3138125    False
# 3138126    False
# 3138127    False
# Name: AREA NAME, Length: 3080288, dtype: bool

# %% [markdown]
# Both Area and Area Name have no missing or blank values and can be used for analysis.
# There are 21 distinct area, which are represented by a unique numeric code.
#
# 77th Street, Southwest, Central have high crime rates. But they just cover more people compared to the size/population of the area. Foothill or Topanga are less dense areas, so lower crime rate makes sense.

# %% [markdown]
# f) Organizing Crime Description by Columns

# %%
# To drop Crm cd1, Crm cd 2, Crm cd 3, Crm cd 4, Weapon Used Cd, and Cross Street

T_crime_unique=T_crime_unique.drop(["Crm Cd 1", "Crm Cd 2", "Crm Cd 3", "Crm Cd 4","Mocodes","Weapon Used Cd", "Weapon Desc", "Cross Street"], axis = 1)

#Organized the Crime Decription by Columns

crime_counts = T_crime_unique.groupby(['Crm Cd', 'Crm Cd Desc']).size().reset_index(name='count')

# Verifying Crime Sorted/Grouped for Top 15 Crimes

crime_counts.sort_values('count', ascending=False).head(15)
# Out:
#      Crm Cd                                        Crm Cd Desc   count
# 58      510                                   VEHICLE - STOLEN  271675
# 63      624                           BATTERY - SIMPLE ASSAULT  261913
# 15      330                              BURGLARY FROM VEHICLE  222897
# 13      310                                           BURGLARY  202541
# 38      440                 THEFT PLAIN - PETTY ($950 & UNDER)  200695
# 26      354                                  THEFT OF IDENTITY  187848
# 81      740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  168240
# 65      626                  INTIMATE PARTNER - SIMPLE ASSAULT  158205
# 6       230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  144407
# 28      420    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  127836
# 4       210                                            ROBBERY  114493
# 82      745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  114172
# ...

# %% [markdown]
# Battery - Simple Assault (15%), Vehicle - Stolen (14%), Burglary from Vehicles (11%), these three crimes account for 40% of all the incidents.
#
# Property Crimes like Burglary, Vehicle theft, petty thefts and vandalism make up a large chunk of the total crimes, which suggests that alot of these crimes are reported or happens rather than the major violent crimes.

# %%
#Grouping the T_crimes by Crime Description for the graph below

TOP_N = 15
crime_counts_orig = (
    T_crime.groupby('Crm Cd Desc', dropna=False)
           .size()
           .reset_index(name='count')
)
top_15_crimes = (
    crime_counts_orig.sort_values('count', ascending=False)
                     .head(TOP_N)['Crm Cd Desc']
)
# Counts by sex for ONLY those top crimes (keep Unknowns together)
crime_sex_counts = (
    T_crime[T_crime['Crm Cd Desc'].isin(top_15_crimes)]
      .assign(Vict_Sex=T_crime['Vict Sex'].fillna('Unknown'))
      .groupby(['Crm Cd Desc', 'Vict_Sex'], dropna=False)
      .size()
      .reset_index(name='count')
)
# Order y-axis by total counts so every facet shares the same order
y_order = (crime_sex_counts.groupby('Crm Cd Desc')['count']
           .sum().sort_values(ascending=False).index.tolist())
plt.figure(figsize=(12,8))

# %% [markdown]
# g) Consolidated Yearly Tables into one Dataset with a Year + Month Column, Removed Preamble/Titles, and Dropped Unnecessary Rows Within Employment Data Set

# %%
path= '/content/drive/MyDrive/780_Project/Shared Folder/Original_1990-2025 employment & unemployment.csv'

# Read Entire CSV With No Header (Includes Title Rows)
raw = pd.read_csv(path, header=None)

# Normalize First Column For Matching (String Type + Trim Whitespace)
s = raw[0].astype(str).str.strip()

# Locate First True Data Row (First Cell That Is Exactly A 4-Digit Year)
first_year_idx = s.str.fullmatch(r"\d{4}").idxmax()

# Keep Rows From First Year Down (Drop Cover/Preamble Above The Table)
raw = raw.iloc[first_year_idx:]

# Recompute Cleaned First Column After Slicing (Stay Aligned With New Frame)
s = raw[0].astype(str).str.strip()

# Build Year Labels From 4-Digit Rows And Forward-Fill To Month Rows
# This Copies The Year Down So Each Month Has The Correct Year
year = pd.to_numeric(s.where(s.str.fullmatch(r"\d{4}")), errors="coerce").ffill()

# Map Month Names To Numbers
MONTHS = {
    'january':1,'february':2,'march':3,'april':4,'may':5,'june':6,
    'july':7,'august':8,'september':9,'october':10,'november':11,'december':12
}

# Select Monthly Rows And Exclude Annual Averages (Keep Only True Months)
mask = s.str.lower().isin(MONTHS) & ~s.str.lower().str.startswith("annual averages")

# Derive Output Column Names From First-Year Row (Use Columns 1–4 As Headers)
h1, h2, h3, h4 = raw.loc[first_year_idx, 1:4].astype(str).str.strip().tolist()

# Convert Month Names To Numbers For Monthly Rows
mnum = s[mask].str.lower().map(MONTHS).astype(int)

# Build YYYY-MM Keys
ym = year[mask].astype(int).astype(str) + "-" + mnum.astype(str).str.zfill(2)

# Assemble Tidy Table: One Row Per Month With Four Series Columns
LA_out = pd.DataFrame({
    "ym": ym,
    h1: raw.loc[mask, 1],
    h2: raw.loc[mask, 2],
    h3: raw.loc[mask, 3],
    h4: raw.loc[mask, 4],
}).reset_index(drop=True)

LA_out[h1] = pd.to_numeric(LA_out[h1].astype(str).str.replace(",", ""), errors="coerce")
LA_out[h2] = pd.to_numeric(LA_out[h2].astype(str).str.replace(",", ""), errors="coerce")
LA_out[h3] = pd.to_numeric(LA_out[h3].astype(str).str.replace(",", ""), errors="coerce")
LA_out[h4] = pd.to_numeric(LA_out[h4].astype(str).str.rstrip("%").str.replace(",", ""), errors="coerce") / 100

# Preview First 5 Rows (Check)
print(LA_out.shape)
print(LA_out.head())
# Out:
# (432, 5)
#         ym  Labor Force  Employment  Unemployment  Unemp. Rate
# 0  2025-01    5097500.0   4802500.0      295000.0        0.058
# 1  2025-02    5060200.0   4762300.0      297900.0        0.059
# 2  2025-03    5047400.0   4767900.0      279600.0        0.055
# 3  2025-04    5095500.0   4834200.0      261300.0        0.051
# 4  2025-05    5049600.0   4776000.0      273600.0        0.054

# %% [markdown]
# **Takeaway:**
#
# During the data cleaning phase, we first reviewed the structure, schema, and summary statistics of the datasets to familiarize ourselves with their contents. We then merged two crime datasets by aligning column formats and data types, removed duplicate crime IDs, combined records from multiple years, and standardized date and time formats to ensure consistency. In addition, we addressed missing values and reformatted categorical variables to support tidy data principles. These steps not only improved the reliability and interpretability of the data but also minimized potential biases introduced by inconsistent formatting, missing entries, or duplicate records, thereby creating a solid foundation for accurate analysis and visualization.

# %% [markdown]
# ## Section 4: Merge Two Datasets

# %%
T_crime_unique[['DATE OCC_MonthYear']].head(5)

# change 'Date OCC_month Year' column name to 'ym', same with the columns name in LA_out
T_crime_unique = T_crime_unique.rename(columns={'DATE OCC_MonthYear': 'ym'})
print(T_crime_unique.columns)

# different dtype, so convert them into the same dtype
T_crime_unique['ym'] = T_crime_unique['ym'].astype(str)
LA_out['ym'] = LA_out['ym'].astype(str)

# Merge LA_out with T_crime_unique using the same column called 'ym'
merged_df2 = T_crime_unique.merge(LA_out, on='ym', how='left')
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Vict Age',
#        'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc', 'Status',
#        'Status Desc', 'LOCATION', 'LAT', 'LON', 'Date Rptd_clean',
#        'Date Rptd_Year', 'Date Rptd_Month', 'Date Rptd_Day',
#        'Date Rptd_MonthYear', 'DATE OCC_clean', 'DATE OCC_Year',
#        'DATE OCC_Month', 'DATE OCC_Day', 'ym'],
#       dtype='object')

# %%
# Merge LA_out with T_crime_unique using the same column called 'ym'
merged_df2 = T_crime_unique.merge(LA_out, on='ym', how='left')

# Optional: check the first rows
print(merged_df2.columns)
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Vict Age',
#        'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc', 'Status',
#        'Status Desc', 'LOCATION', 'LAT', 'LON', 'Date Rptd_clean',
#        'Date Rptd_Year', 'Date Rptd_Month', 'Date Rptd_Day',
#        'Date Rptd_MonthYear', 'DATE OCC_clean', 'DATE OCC_Year',
#        'DATE OCC_Month', 'DATE OCC_Day', 'ym', 'Age Group', 'Labor Force',
#        'Employment', 'Unemployment', 'Unemp. Rate'],
#       dtype='object')

# %% [markdown]
# In this step, we standardized the column names and data types between the crime dataset and the employment&unemployment dataset to ensure they could be merged accurately. By renaming the date column to a consistent format (ym) and converting both columns to the same data type, we successfully merged the two datasets based on their year-month values. This integration provides a unified dataset, allowing us to analyze the relationship between crime patterns and unemployment&employment trends over time.

# %% [markdown]
# ## Section 5: Visualizations

# %% [markdown]
# ### 5.1 Crime Analysis by Date and Area

# %%
COLORS = {"primary_blue":"#2563EB","accent_gold":"#FDBA74","light_blue":"#93C5FD"}
palette = [COLORS['primary_blue'], COLORS['accent_gold'], COLORS['light_blue']]
YEAR_COLORS = {
    2018: '#93C5FD',
    2019: '#60A5FA',  # cornflower
    2020: '#0EA5E9',  # sky/cyan
    2021: '#2563EB',  # primary blue
    2022: '#1E3A8A',  # deep navy
    2023: '#FDBA74',  # accent gold
    2024: '#14B8A6',  # teal
    2025: '#8B5CF6'
}

sns.set_theme(style="whitegrid", context="notebook")
sns.set_palette(palette)

# %% [markdown]
# #### 5.1.1 Top 15 types of Crimes in LA
# What is the top 15 crimes in the city of LA?

# %%
top_15_crimes = crime_counts.sort_values('count', ascending=False).head(15)
plt.figure(figsize=(12,6))
n = len(top_15_crimes)
grad = sns.light_palette(COLORS['primary_blue'], n_colors=n, reverse=True)
sns.barplot(
    data=top_15_crimes,
    x='count',
    y='Crm Cd Desc',
    palette=grad
)
plt.title("Top 15 Crimes by Count", fontsize=16, weight='bold')
plt.xlabel("Number of Records", fontsize=12)
plt.ylabel("Crime Type", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1029799213.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# This bar chart ranks offenses by total reports citywide. Vehicle theft is the most common by a wide margin, followed by battery – simple assault. Next are burglary from vehicle and burglary, with petty theft ($950 & under), identity theft, and felony vandalism also high. Mid-table offenses include intimate partner – simple assault, aggravated assault, and theft from motor vehicle (petty), while robbery, misdemeanor vandalism, grand theft, shoplifting (petty), and criminal threats (no weapon displayed) round out the top 15. Overall, the list is dominated by property/theft-related crimes, with violent offenses appearing but in smaller totals.

# %% [markdown]
# #### 5.1.2 Yearly Trend of Top 5 Crimes in LA (2018–2024)
# How did major crime types change year to year from 2018 to 2024, and which categories show the biggest swings?

# %%
# Ensure ym is datetime
merged_df2['ym'] = pd.to_datetime(merged_df2['ym'], format='%Y-%m')

# Filter 2018–2023
crime_2018_2024 = merged_df2[(merged_df2['ym'] >= '2018') & (merged_df2['ym'] <= '2024-12')]

# Extract year
crime_2018_2024['Year'] = crime_2018_2024['ym'].dt.year

# Identify top 5 crimes overall
top_crimes = crime_2018_2024['Crm Cd Desc'].value_counts().head(8).index.tolist()

# Aggregate yearly counts for top 8 crimes
yearly_top_crimes = (crime_2018_2024[crime_2018_2024['Crm Cd Desc'].isin(top_crimes)]
    .groupby(['Year', 'Crm Cd Desc'])
    .size()
    .reset_index(name='Crime_Count')
)

plt.figure(figsize=(8,6))
sns.lineplot(
    data=yearly_top_crimes,
    x='Year',
    y='Crime_Count',
    hue='Crm Cd Desc',
    palette='tab10'
)

plt.title('Yearly Trend of Top 8 Crimes in LA (2018–2024)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.xticks(yearly_top_crimes['Year'].unique())
plt.grid(alpha=0.3, linestyle='--')

# Make the legend smaller
plt.legend(title='Crime Type', title_fontsize=8, fontsize=6, loc='upper left')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1414223919.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_2018_2024['Year'] = crime_2018_2024['ym'].dt.year

# %% [markdown]
# This line chart shows yearly trends in top crime types in Los Angeles from 2018 to 2024. Patterns differ by offense: vehicle theft dips in 2019, then climbs sharply through 2022 before easing in 2023. Identity theft is mostly steady until a pronounced spike in 2022—likely tied to the post-pandemic shift toward online banking and shopping, which expanded opportunities for phishing and fraud. Battery, burglary, and petty theft decline modestly from 2019 to 2020 and then remain roughly flat.

# %% [markdown]
# #### 5.1.3 Monthly Trend of Total Crimes for Four Years (2021–2024)
#
# What is the monthly trend of total crimes for five years?

# %%
T_crime_unique['year'] = T_crime_unique['Date Rptd'].dt.year
T_crime_unique['month'] = T_crime_unique['Date Rptd'].dt.month
# Filter for 2020–2024
crime_filtered = T_crime_unique[
    (T_crime_unique['year'] >= 2020) & (T_crime_unique['year'] <= 2024)
]
# Group by year and month, count number of records
crime_monthly = (
    crime_filtered.groupby(['year', 'month'])
    .size()
    .reset_index(name='count')
)
# Pivot for plotting
pivot = crime_monthly.pivot(index='month', columns='year', values='count').fillna(0)
plt.figure(figsize=(8,5))
for y in pivot.columns:
    plt.plot(
        pivot.index, pivot[y],
        marker='o', linewidth=2,
        color=YEAR_COLORS.get(int(y), COLORS['primary_blue']),
        label=str(y)
    )
plt.title('Total Crimes by Month (2020–2024)', fontsize=14, weight='bold')
plt.xlabel('Month')
plt.ylabel('Number of Crimes')
plt.xticks(range(1, 13))
plt.legend(title='Year')
plt.tight_layout()
plt.show()

# %% [markdown]
# Conclusion:
#
# Here, we have taken only 5 years to see the trend analysis in more clearly while giving enough historical context for analysis. We are not taking 2025 as we are still in October, so the data will still be incomplete and will not be comparable to full year patterns.
#
# The crime levels have clear seasonal pattern across all the years, experiencing peaks and dips in certain months.
#
# 2024 stands out having significantly lower crime counts due to actual crime incident reductions, and a change in the LAPD data collection system, hence there could be difference in the counting methodology

# %% [markdown]
# #### 5.1.4. Crime by Hour of the Day
#
# How does crime vary across the 24-hour day, and when are the peak and low periods?

# %%
#Crime Count by Hour of the Day

T_crime_unique['HOUR'] = T_crime_unique['TIME OCC'].str[:2].astype(int)

# Group by hour and count crimes
hourly_counts = T_crime_unique.groupby('HOUR').size()

# Plot
plt.figure(figsize=(10,6))
plt.bar(hourly_counts.index, hourly_counts.values, width=0.8, edgecolor='black')
plt.xticks(range(0,24))
plt.xlabel("Hour of Day (24-hour format)")
plt.ylabel("Number of Crimes")
plt.title("Crimes by Hour of the Day")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# This chart shows that crime is not evenly distributed across the day. During work hours(9AM-6PM), crime levels rise steadily and reach their highest point at noon (12PM), making daytime the peak period for criminal activity. There are different reasons such as higher activity levels for many businesses, shops, and offices at midday, which attracts potential crimes like theft, robbery and break-ins. In contrast, during leisure hours (7 PM–midnight), crime remains increased but does not exceed the midday peak, instead staying relatively stable before gradually declining after midnight. From 12 AM to 6 AM, the number of crimes decreases significantly, with the early morning being the least active period. This pattern suggests that crime is strongly linked to periods of high social and economic activity.

# %% [markdown]
# #### 5.1.5. Crime Count by Area and Date
#
#
# In the areas with the highest crime counts, have crime levels increased over time, and what overall trends can be observed across the top 10 crime areas?

# %%
#Heatmap of Crime Count and Date:

# Extract Year
T_crime_unique["Year"] = T_crime_unique["Date Rptd"].dt.year

# Count Crimes per Area × Year
crime_counts_year = (T_crime_unique.groupby(["AREA NAME", "Year"]).size().reset_index(name="Crime Count"))

# Pick the Top 10 Areas by Total Crimes
N = 10
top_areas = (crime_counts_year.groupby("AREA NAME")["Crime Count"].sum().nlargest(N).index)

cc = crime_counts_year[crime_counts_year["AREA NAME"].isin(top_areas)].copy()

# Make this Data into a Heatmap Format
grid_year = cc.pivot(index="AREA NAME", columns="Year", values="Crime Count").fillna(0)

# Order rows by total crime
grid_year = grid_year.loc[grid_year.sum(axis=1).sort_values(ascending=False).index]

# Now to Plot
plt.figure(figsize=(10,6))
sns.heatmap(
    grid_year,
    cmap=sns.light_palette("#1B4BCB", as_cmap=True),
    robust=True,
    linewidths=0.3, linecolor="white",
    cbar_kws={"label": "Crime Count"},
)


plt.title(f"Crime Counts by Area and Year (Top {N} Areas)")
plt.xlabel("Year")
plt.ylabel("Area")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# The heatmap shows that crime counts in the top 10 areas are not uniform over time. Some areas, such as Central, experienced a significant increase from 2010 to 2021, but peaked sharply in 2022 and 2023 compared with other areas. This may belong to the central areas that have commercial centers, and wealthy communities. Other areas, including 77th Street and Southwest, maintained consistently high crime levels from 2010 to 2023, with only moderate fluctuations. In contrast, places like Hollywood and Van Nuys show relatively stable or slightly declining trends. Southeast shows moderate crime levels across most years, except in 2015 and 2016 when the number of crimes dropped sharply.Overall, the trend indicates that while some neighborhoods remain persistent hotspots, others show changing crime dynamics, highlighting the importance of localized analysis.

# %% [markdown]
# #### 5.1.6 Crime Density by Area
#
# Where are the geographic crime hotspots across LA from 2018 to 2023, and which divisions have the highest crime density?

# %%
# Ensure ym is datetime
merged_df2['ym'] = pd.to_datetime(merged_df2['ym'], format='%Y-%m')

# Filter the date range
crime_2018_2024 = merged_df2[
    (merged_df2['ym'] >= '2018-01-01') &
    (merged_df2['ym'] <= '2024-12-31')
].copy()

# Group by Area Name and count crimes
area_counts = (
    crime_2018_2024
    .groupby('AREA NAME')
    .size()
    .reset_index(name='Crime_Count')
    .sort_values('Crime_Count', ascending=False)
)

# Set 'area name' as index if you prefer
area_counts = area_counts.set_index('AREA NAME')

# Show top 20
print(area_counts.head(20))
# Out:
#              Crime_Count
# AREA NAME
# Central            86286
# 77Th Street        84260
# Southwest          77072
# Pacific            75832
# Hollywood          68924
# Southeast          68101
# N Hollywood        67095
# Olympic            65619
# Newton             65482
# Wilshire           63167
# Rampart            60479
# West La            59686
# Northeast          57717
# Van Nuys           57234
# Topanga            56137
# West Valley        55121
# Devonshire         54527
# Mission            54390
# Harbor             53939
# Hollenbeck         49981

# %%
area_location = (crime_2018_2024
               .groupby('AREA NAME')
               .agg({'LAT': 'mean', 'LON': 'mean', 'DR_NO': 'count'})
               .reset_index()
               .rename(columns={'DR_NO': 'Crime_Count'}))

plt.figure(figsize=(12, 10))
scatter = plt.scatter(area_location['LON'],
                     area_location['LAT'],
                     s=area_location['Crime_Count']*0.08,
                     c=area_location['Crime_Count'],
                     cmap = sns.color_palette("PuBu", as_cmap=True),
                     alpha=0.6,
                     edgecolors='black',
                     linewidth=1)

plt.colorbar(scatter, label='Crime Count')
plt.title('Crime Density by Area in LA (2018–2024)', fontsize=16)
plt.xlabel('Longitude', fontsize=12)
plt.ylabel('Latitude', fontsize=12)
plt.grid(True, alpha=0.3)

# Add area labels
for _, row in area_location.iterrows():
    plt.annotate(row['AREA NAME'],
                (row['LON'], row['LAT']),
                fontsize=8,
                ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# This bubble chart visualizes the geographic distribution and density of crime across Los Angeles police divisions from 2018 to 2024.
#
# The Central Division stands out dramatically as the highest crime area in Los Angeles, with approximately 85,000+ crimes during this period. Represented by the darkest and largest bubble, it is located in the downtown LA area and shows significantly higher crime density than all other divisions. This extreme concentration reflects Central's role as the city's commercial and business hub, where high daytime populations and heavy foot traffic create more opportunities for crime.The second tier of high-crime areas includes the 77th Street, Pacific, and Southwest divisions, each recording between 60,000 and 70,000 crimes. These areas are clustered together in the South LA region, forming a concentrated zone of elevated crime activity. This southern concentration, combined with Central's downtown dominance, creates the most intense crime corridor in Los Angeles.A ring of moderate-high crime areas surrounds the central core, including Newton, Rampart, Wilshire, Olympic, and Hollenbeck divisions. These areas show crime counts ranging from 60,000 to 70,000 and are tightly clustered in central LA, forming the broader urban crime zone.
#
# Several clear geographic patterns emerge from this visualization. First, there is a strong central cluster dominance, with the highest crime concentration forming a tight grouping in downtown and South LA. Second, a distinct north-south divide is evident, with northern areas showing significantly lower crime than southern and central regions. Third, a core-periphery pattern shows that areas on the edges of LA have substantially lower crime compared to the urban core. The difference between the darkest area (Central) and the lightest areas is nearly twofold, demonstrating the dramatic spatial inequality in crime distribution.

# %% [markdown]
# #### 5.1.7 Monthly Crime by Areas
#
# Which LAPD areas have the highest typical monthly crime levels, and which show the most month-to-month variability?

# %%
merged_df2['ym'] = pd.to_datetime(merged_df2['ym'], format='%Y-%m') # Make sure ym is datetime, it was object

crime_2018_2024 = merged_df2[(merged_df2['ym'] >= '2018-01') & (merged_df2['ym'] <= '2024-12')] # Filter data for 2018–2023

# Aggregate monthly crime counts by area
monthly_by_area = (
    crime_2018_2023
    .groupby(['AREA NAME', crime_2018_2024['ym'].dt.to_period('M')])
    .size()
    .reset_index(name='Crime_Count')
)

# Extract Year-Month for plotting
monthly_by_area['Date'] = monthly_by_area['ym'].dt.to_timestamp()

# Calculate median crime per area
area_medians = monthly_by_area.groupby('AREA NAME')['Crime_Count'].median().sort_values(ascending=False)

# Select top 10 areas
top_areas = area_medians.head(10).index
monthly_top_areas = monthly_by_area[monthly_by_area['AREA NAME'].isin(top_areas)]

# Set category order for plotting
monthly_top_areas['AREA NAME'] = pd.Categorical(
    monthly_top_areas['AREA NAME'],
    categories=top_areas,
    ordered=True
)
# Define a list of 10 colors (one for each area)
colors = ['skyblue', 'lightgreen', 'salmon', 'plum', 'gold', 'lightcoral', 'lightskyblue', 'orange','crimson','CornFlowerBlue']
sns.boxplot(
    x='AREA NAME',
    y='Crime_Count',
    data=monthly_top_areas,
    order=top_areas,
    palette=colors  # instead of palette
)

plt.title('Monthly Crime Counts: Top 10 Areas (2018–2024)', fontsize=14, fontweight='bold')
plt.xlabel('Area', fontsize=12)
plt.ylabel('Monthly Crime Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True, alpha=0.3, axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2695556290.py:24: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-2695556290.py:31: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# This box plot displays the monthly crime counts for the top 10 areas in Los Angeles between 2018 and 2023. Each box shows the distribution of monthly crime incidents within that area, with the median represented by the central line and circles indicating outliers.
#
# 77th Street’s box is positioned highest, indicating it has the highest typical (median) crime rate. Central’s box is the tallest and widest, showing the greatest month-to-month variation and the highest overall crime counts, which suggests frequent spikes and high variability in crime activity. In contrast, areas like Newton and Wilshire have shorter boxes, meaning their crime levels are more stable and generally lower.

# %% [markdown]
# ### 5.2 Correlation between Unemployment and Crime Count

# %% [markdown]
# #### 5.2.1 Monthly Crime vs Unemployment Correlation by Area
#
# Do unemployment and crime move together across neighborhoods, or does the relationship differ by area?

# %%
# Filter by year 2018–2024
monthly_by_area = monthly_by_area[
    (monthly_by_area['ym'] >= '2018-01') &
    (monthly_by_area['ym'] <= '2024-12')
]


merged_df2['ym'] = pd.to_datetime(merged_df2['ym'])
monthly_by_area = (
    merged_df2
    .groupby(['AREA NAME', 'ym'])
    .size()
    .reset_index(name='Crime_Count')
)

# Add unemployment rate (already in merged_df2)
# If it's already per month, merge directly
monthly_by_area = monthly_by_area.merge(
    merged_df2[['ym', 'Unemp. Rate']].drop_duplicates(),
    on='ym',
    how='left'
)
# Correlation of crime vs unemployment per area
area_corr = monthly_by_area.groupby('AREA NAME').apply(
    lambda x: x['Crime_Count'].corr(x['Unemp. Rate'])
).reset_index(name='Correlation')

# Sort descending by correlation
area_corr = area_corr.sort_values('Correlation', ascending=False)
print(area_corr)
# Out:
#       AREA NAME  Correlation
# 3      Foothill     0.196868
# 4        Harbor     0.153805
# 7       Mission     0.143482
# 14    Southeast     0.077452
# 10    Northeast     0.059388
# 0   77Th Street     0.029808
# 2    Devonshire     0.006506
# 15    Southwest    -0.000124
# 17     Van Nuys    -0.054254
# 19  West Valley    -0.064538
# 8   N Hollywood    -0.072116
# 16      Topanga    -0.077423
# 18      West La    -0.090745
# 9        Newton    -0.182560
# 5    Hollenbeck    -0.182882
# 12      Pacific    -0.199019
# 13      Rampart    -0.203827
# 11      Olympic    -0.268748
# 20     Wilshire    -0.292843
# 6     Hollywood    -0.294590
# 1       Central    -0.563195
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(area_corr['AREA NAME'], area_corr['Correlation'], color=COLORS['primary_blue'])
plt.xticks(rotation=45)
plt.ylabel('Correlation with Unemployment Rate')
plt.title('Monthly Crime vs Unemployment Correlation by Area')
plt.show()

# %% [markdown]
# From this chart of the monthly crime and unemployment correlation, it illustrated that Mission, Foothill, Harbor, and Southeast show the strongest positive correlations (around 0.15-0.25). This means in these areas, when unemployment goes up, crime also tends to go up. About 6 areas show positive correlations, suggesting unemployment and crime move together. On the other side, Hollywood, Central, Wilshire, Rampart, and Pacific show strong negative correlations (around -0.2 to -0.6). To be more specific, central has the strongest negative correlation (approximately -0.55). This means in these areas, when unemployment goes up, crime actually goes down. Moreover, Several areas like Southwest, Van Nuys show correlations close to zero, indicating little to no relationship between unemployment and crime.
#
# Overall, this relationship between unemployment and crime is not consistent across areas. Some areas follow the expected pattern (higher unemployment = more crime), while others show the opposite trend. This suggests that local factors, demographics, policing strategies, or community characteristics may play a more important role than unemployment alone in determining crime rates.
#
# For next step, we will do the annual crime trend based on these six areas with different correlation degree:
#
#         Area Name Correlation
#
# - 3     Foothill    0.196868
# - 7     Mission     0.143482
# - 15    Southwest   -0.000124
# - 17    Van Nuys    -0.054254
# - 6     Hollywood   -0.294590
# - 1     Central     -0.563195

# %% [markdown]
# #### 5.2.2 Annual Trend of Top 8 Crimes Across Selected Areas (2018–2024)
#
# How do yearly crime levels and crime-type composition change across the selected neighborhoods?

# %%
# Areas of interest
areas_of_interest = ['Mission','Foothill','Southwest','Van Nuys','Hollywood','Central']

# Ensure 'ym' is datetime
merged_df2['ym'] = pd.to_datetime(merged_df2['ym'])

# Filter data for 2018–2023 and selected areas
df_area = merged_df2[
    (merged_df2['ym'] >= '2018-01') &
    (merged_df2['ym'] <= '2024-12') &
    (merged_df2['AREA NAME'].isin(areas_of_interest))
].copy()

# Rename crime column to lowercase
df_area = df_area.rename(columns={'Crm Cd Desc': 'Crm Cd Desc'})

# Top 8 crimes
top_crimes = df_area['Crm Cd Desc'].value_counts().head(8).index.tolist()
df_top_crimes = df_area[df_area['Crm Cd Desc'].isin(top_crimes)].copy()

# Add year column
df_top_crimes['year'] = df_top_crimes['ym'].dt.year

# Aggregate counts per year, area, and crime
annual_trend = df_top_crimes.groupby(['AREA NAME','year','Crm Cd Desc']).size().reset_index(name='Crime_Count')

# Fixed color palette for consistency
palette = sns.color_palette("tab10", n_colors=len(top_crimes))
crime_colors = dict(zip(top_crimes, palette))

# %%
fig = px.area(
    annual_trend,
    x='year',
    y='Crime_Count',
    color='Crm Cd Desc',
    facet_col='AREA NAME',
    facet_col_wrap=3,
    line_group='Crm Cd Desc',
    labels={'Crime_Count':'Crime Count','Crm Cd Desc':'Crime Type'},
    title='Annual Trend of Top 8 Crimes Across Selected Areas (2018–2023)',
    color_discrete_sequence=px.colors.qualitative.Set1
)

fig.update_layout(
    height=700,
    title_font_size=20,
    legend_title_text='Crime Type'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Based on the previous analysis, we chose these six areas for deeper analysis. High positive correlation: Mission (+0.23), Foothill (+0.21) - areas where unemployment and crime move together; Near zero correlation: Southwest (+0.01), Van Nuys (-0.04) - areas with weak/no relationship; Strong negative correlation: Hollywood (-0.28), Central (-0.56) - areas with inverse relationship.
#
# Mission and Foothill are primarily residential areas with lower total crime counts (approximately 3k-5k annually) and relatively stable trends with minimal fluctuations. These areas are more likely working-class or lower-income neighborhoods where residents may be more economically vulnerable. During unemployment periods, economic hardship can lead to higher crime rates, showing a positive correlation between unemployment and crime.
#
# Central and Hollywood are commercial and tourist centers where crimes follow foot traffic and economic activity. High employment means busy streets, crowded businesses, and more tourists, creating more opportunities for theft, vehicle theft, and identity theft, as shown in the chart. When unemployment rises, these areas see emptier streets and closed businesses, resulting in fewer potential victims and thus lower crime rates. This explains the negative correlation.
#
# Southwest and Van Nuys show near-zero correlation and may have more diverse populations with a mix of homeowners and renters. Southwest has the second-highest crime volume (~5k-7k) with a more volatile pattern and fluctuations throughout the period, where vehicle theft (pink) appears to be a major contributor. Van Nuys shows a relatively stable pattern around 4k-5k crimes with less dramatic fluctuations compared to other areas. The mixed demographic and economic characteristics in these areas result in weak relationships between unemployment and crime.

# %% [markdown]
# ### 5.3 Top 15 Crimes by Victim Sex

# %% [markdown]
# #### 5.3.1 Victim's Gender affected by the Total Crimes
# What are the top 15 crimes during these years, and does the victim's gender distribution are different across different crime types? To be more specific, which crimes have the highest proportion of female victims?

# %%
# Pivot so Each Sex is a Column (M/F/Unknown as Separate Columns per Crime Type)
pivot_data = crime_sex_counts.pivot(index='Crm Cd Desc',
                                    columns='Vict_Sex',
                                    values='count').fillna(0)

# Reorder Rows According to a Pre-Computed Order (y_order, from earlier step)
pivot_data = pivot_data.loc[y_order]

# Ensure All Three Columns Exist, Even if One Category is Missing in the Data
for col in ['M','F','Unknown']:
    if col not in pivot_data.columns:
        pivot_data[col] = 0

# Compute Total Victims Per Crime Type
totals = pivot_data[['M','F','Unknown']].sum(axis=1)

# Compute Share (Percentage of Each Sex Per Crime Type)
# e.g., row sum = 100, M=60 → share=0.6
shares = pivot_data[['M','F','Unknown']].div(totals, axis=0).fillna(0)
plt.figure(figsize=(12, 8))

# Define Fixed Colors for Each Sex Using Your Color Scheme
colors = {'M': COLORS['primary_blue'], 'F': COLORS['accent_gold'], 'Unknown': COLORS['light_blue']}

# Initialize "Left" Positions for Stacking (Start at 0 for All Rows)
left = np.zeros(len(pivot_data))
ax = plt.gca()

# Y Positions of Each Crime Type (Rows)
ypos = np.arange(len(pivot_data.index))

# Loop over each sex and plot its stacked segment
for sex in ['M', 'F', 'Unknown']:
    vals = pivot_data[sex].values   # absolute counts for this sex

    # Draw horizontal bars stacked on "left"
    ax.barh(pivot_data.index, vals, left=left,
            label={'M':'Male','F':'Female','Unknown':'Unknown'}[sex],
            color=colors[sex])

    # Convert fractions to percentages
    pcts = (shares[sex].values * 100.0)

    # Loop row by row: l = starting x, w = width (count), p = percent
    for i, (l, w, p) in enumerate(zip(left, vals, pcts)):
        if w <= 0:    # skip if no bar to draw
            continue
        x_center = l + w/2.0   # midpoint of the bar segment

        # If segment is big enough, draw percentage INSIDE the bar
        if p >= 4:  # threshold: at least 4% of total
            ax.text(x_center, i, f"{p:.1f}%", ha='center', va='center',
                    fontsize=9, color='white', fontweight='bold')
        else:
            # Otherwise draw just outside the bar so text is visible
            ax.text(l + w + totals.max()*0.006, i, f"{p:.1f}%", ha='left', va='center',
                    fontsize=8, color='black')
    # Update "left" so the next segment stacks on top of this one
    left += vals

# Extend x-axis a little to make room for labels placed outside bars
ax.set_xlim(0, totals.max() * 1.12)

#Plot
plt.title(f"Top {TOP_N} Crimes by Victim Sex (Stacked with % Labels)", fontsize=16, weight='bold')
plt.xlabel("Number of Records")
plt.ylabel("Crime Type")
plt.legend(title="Victim Sex")
plt.tight_layout()
plt.show()

# %% [markdown]
# This chart shows the top 15 crimes include a mix of property offenses (such as shoplifting, theft, and burglary) and personal offenses (such as assault, robbery, and criminal threats). Victim gender distribution varies notably across these categories. Male victims dominate in crimes like shoplifting -assault with a deadly weapon (72.6% male), and robbery (69.8% male). In contrast, female victims are most heavily represented in intimate partner – simple assault (78.7% female), followed by theft of identity (52.8% female) and battery – simple assault (50.6% female). This indicates that while men are more often victims of violent street crimes and theft, women are affected by domestic violence and identity-related crimes.

# %% [markdown]
# ####5.3.2  Victim Distribution by Race
# Is there a difference between different races in terms of victims numbers?

# %%
#Data cleaning:
#Create a new dataset to show the full name of each descent letter
descent_mapping = {
    'A': 'Other Asian',
    'B': 'Black',
    'C': 'Chinese',
    'D': 'Cambodian',
    'F': 'Filipino',
    'G': 'Guamanian',
    'H': 'Hispanic/Latino',
    'I': 'American Indian/Alaskan Native',
    'J': 'Japanese',
    'K': 'Korean',
    'L': 'Laotian',
    'O': 'Other',
    'P': 'Pacific Islander',
    'S': 'Samoan',
    'U': 'Hawaiian',
    'V': 'Vietnamese',
    'W': 'White',
    'X': 'Unknown',
    'Z': 'Asian Indian'
}
from matplotlib.ticker import StrMethodFormatter
#Groups the dataset by the victims' descent code
victim_by_race = (
    T_crime.groupby('Vict Descent')
    .size()
    .reset_index(name='count')
    .sort_values('count', ascending=False)
    .head(10)
)
#Converts short race codes into long full labels
victim_by_race['Vict Descent'] = victim_by_race['Vict Descent'].map(descent_mapping).fillna('Other/Unknown')
victim_by_race = victim_by_race.sort_values('count', ascending=False)

#Visualization:
#Draft a barplot to visualize
plt.figure(figsize=(12,6))
ax = sns.barplot(
    data=victim_by_race,
    x='count',
    y='Vict Descent',
    hue='Vict Descent',
    palette='viridis'
)
#Format the numbers
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))
#Add labels
plt.title('Crime Victims by Race', fontsize=16, weight='bold')
plt.xlabel('Number of Reports')
plt.ylabel('Victim Descent')
plt.tight_layout()
plt.show()

# %% [markdown]
# According to the plot, the number of Hispanic victims is the largest, followed by the white people and black people. However, white people make up most of the population in the area. This graph shows that the victim percentage is not distributed as the population. This could be cause of social and structural issues, policy issues, system inequalities and more. Living in a vulnerable neighborhood is usually the major cause of the problem.

# %% [markdown]
# ####5.3.3 Victim Age Distribution by Sex
#
# Are the victims evenly distributed among all adults and what would be the age that most crimes target on?

# %%
plt.figure(figsize=(10,6))
sns.violinplot(
    data=merged_df2[merged_df2['Vict Sex'].isin(['M','F'])],
    x='Vict Sex',
    y='Vict Age',
    palette=[COLORS['primary_blue'], COLORS['accent_gold']],
    inner='box',       # shows boxplot inside the violin
    cut=0,             # trims to observed range
    scale='width'      # keeps both violins same width
)
plt.title("Victim Age Distribution by Sex (0 years and older)", fontsize=16, weight='bold')
plt.xlabel("Victim Sex")
plt.ylabel("Victim Age")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3168990455.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#
# /tmp/ipython-input-3168990455.py:2: FutureWarning:
#
#
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.

# %% [markdown]
# We can see the two violin graphs, the blue one represents Males while the other one represents Females. Most of the victims are usually between 20-30 years old and Female victim percentage in this age is even more significant. The vicitim numbers reduce by the age increases and also there are much less victims for those who are teenagers. There is a significant number of 0-year-old victims for Males and it's probably counted whenever their parents were targeted. It's probably related to that people in 20-30 are usually more active in the society and tend to have less self-protection awareness.

# %% [markdown]
# ### 5.4 Unemployment Rate Seasonality in Recent Years

# %% [markdown]
# #### 5.4.1 Unemployment Rate Seasonality in Recent Years
# Do unemployment rates remain consistent throughout the year, or do they show seasonal variation?

# %%
df = LA_out.copy()

# Extract Year/Month From ‘ym’ (Format ‘YYYY-MM’)
df["year_int"] = df["ym"].str.slice(0, 4).astype(int)
df["month"]    = df["ym"].str.slice(5, 7).astype(int)
df["year"]     = df["year_int"].astype(str)   # for hue labels

# Keep Last ~5 Years and Drop 2020 (Extreme Outlier)
recent = df[df["year_int"] >= df["year_int"].max() - 5].copy()

# Plot
ax = sns.lineplot(data=recent, x= "month", y="Unemp. Rate", hue="year", marker="o")
ax.set(title="Unemployment Rate Seasonality in Recent Years",
       xlabel= "month",
       ylabel= "Rate")

plt.tight_layout();
plt.show()

#This line chart tracks monthly unemployment across recent years.
#It highlights a recurring seasonal pattern: rates are comparatively soft in spring, then climb into midsummer before easing later in the year.
#A notable outlier is 2021, which sits at a higher overall level (pandemic recovery).
#These trends could be due to student labor entry, construction project timelines, and late-year hiring shifts.

# %% [markdown]
# This line chart illustrates how unemployment rates in Los Angeles fluctuate across months from 2021 to 2025. The data reveals a clear seasonal pattern - rates tend to dip in the spring, peak during the midsummer months, and gradually decline toward the end of the year. The year 2021 stands out as an outlier, reflecting lingering economic effects of the pandemic recovery. These seasonal shifts likely relate to cyclical labor dynamics, such as student employment, construction projects, and end of year hiring patterns. Understanding these patterns helps contextualize economic trends when analyzing how employment conditions may indirectly relate to crime behavior over time.

# %% [markdown]
# #### 5.4.2 Crime Year Trend, employment and Unemployment Rate
# What is the yearly trend of crime, as well as unemployment rates?

# %%
monthly_crime = (
    merged_df2
    .groupby('ym')                   # group by the year-month column
    .size()                          # count rows in each group
    .reset_index(name='Count')       # reset index and name the count column
)

print(monthly_crime.head())
# Out:
#           ym  Count
# 0 2010-01-01  22647
# 1 2010-02-01  15685
# 2 2010-03-01  17626
# 3 2010-04-01  17277
# 4 2010-05-01  17346

# %%
merged_df2['employment_rate'] = merged_df2['Employment'] / merged_df2['Labor Force'] * 100

# Quick check
merged_df2[['Labor Force','Employment','employment_rate']].head()
# Out:
#    Labor Force  Employment  employment_rate
# 0    5058100.0   4122600.0        81.504913
# 1    4868800.0   4362800.0        89.607295
# 2    4868800.0   4362800.0        89.607295
# 3    4878500.0   4350300.0        89.172902
# 4    4829400.0   4278600.0        88.594857

# %%
merged_df2['Unemp. Rate'] = pd.to_numeric(merged_df2['Unemp. Rate'], errors='coerce')

fig, ax1 = plt.subplots(figsize=(12,5))

# Filter both dataframes to 2018-2023
monthly_crime_filterd = monthly_crime[monthly_crime['ym'].dt.year.between(2018, 2023)].copy() # monthly_crime
merged_df2_filtered = merged_df2[merged_df2['ym'].dt.year.between(2018, 2023)].copy()         # merged_df2

# Left axis: Crime count
sns.lineplot(data=monthly_crime_filterd, x='ym', y='Count', marker='*', ax=ax1, color='CornflowerBlue', label='Crime Count')
ax1.set_xlabel('Year')
ax1.set_ylabel('Crime Count', color='CornflowerBlue')
ax1.tick_params(axis='y', labelcolor='CornflowerBlue')
ax1.tick_params(axis='x', rotation=45)

# Right axis: Unemployment rate
ax2 = ax1.twinx()
sns.lineplot(data=merged_df2_filtered, x='ym', y='Unemp. Rate', marker='x', ax=ax2, color='crimson', label='Unemployment Rate')
ax2.set_ylabel('Unemployment Rate (%)', color='crimson')
ax2.tick_params(axis='y', labelcolor='crimson')

plt.title('Crime Count vs Unemployment Rate (2018–2023)')
fig.tight_layout()
plt.show()

# %% [markdown]
# This line chart displays the monthly crime count and unemployment rate in LA from 2018 to 2023.
#
# The crime counts typically peak at the end of each year and the beginning of the following year, particularly during winter months. One possible explanation is that holiday may lead to more interpersonal conflicts, and vacant properties during the holiday season. These can increase the posibilities of property crimes such as theft or burglary.
#
# For the unemployment rate, the trend remains stable throughout most of the period, except during 2020 to 2021, when there is a sharp peak around mid-2020. Covid-19 pandemic lockdowns forced people to stay home, and many induxtries were temporarily shut down, such as hospitality, restaurants, and supply chains. This economic disruption led to widespread job losses and a sudden rise in unemployment.
#
# This chart does not appear to be a strong direct correlation betwwwen crime counts and unemployment rates. However, during 2020, unemployment spikes dramatically while crime counts drop. With lockdowns in place, public activity declined, which may have led to fewer oppotunities for certain typles of crime.

# %% [markdown]
# #### 5.4.3 Top 10 Positive and Negative Correlations between Crime Types and Unemployment Rate
# Which crime types show the strongest relationship with unemployment rates, and what does this reveal about broader social or economic patterns in Los Angeles?

# %%
# Aggregate total crimes per Area, Crime Type, and Month
crime_counts = (
    merged_df2.groupby(['AREA NAME', 'Crm Cd Desc', 'ym'], as_index=False)
    .size()
    .rename(columns={'size': 'Crime_Count'})
)

crime_unemp = crime_counts.merge(
    merged_df2[['AREA NAME', 'ym', 'Unemp. Rate']].drop_duplicates(),
    on=['AREA NAME', 'ym'],
    how='left'
)


# Correlation of crime vs unemployment per area
corrs = (
    crime_unemp.groupby('Crm Cd Desc')
    .apply(lambda x: x['Crime_Count'].corr(x['Unemp. Rate']))
    .dropna()
    .reset_index(name='Correlation')
    .sort_values(by='Correlation', ascending=False)
)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning:
#
# invalid value encountered in divide
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning:
#
# invalid value encountered in divide
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2914: RuntimeWarning:
#
# Degrees of freedom <= 0 for slice
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:2773: RuntimeWarning:
#
# invalid value encountered in multiply
#
# /tmp/ipython-input-1418940298.py:18: DeprecationWarning:
#
# ...

# %%
top_corrs = corrs.head(10)
bottom_corrs = corrs.tail(10)
subset_corrs = pd.concat([top_corrs, bottom_corrs])

plt.figure(figsize=(8,6))
sns.barplot(data=subset_corrs, y='Crm Cd Desc', x='Correlation', palette='coolwarm')
plt.title('Correlation Between Unemployment Rate and Crime Types (2018–2023)', fontsize=14, fontweight='bold')
plt.xlabel('Correlation Coefficient')
plt.ylabel('')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3917552992.py:6: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# This visualization examines how different crime types correlate with unemployment rates from 2018 to 2023. The results show minimal overall correlation, with only a few crimes - such as purse snatching and child neglect - displaying mild positive associations. Conversely, property related offenses like grand theft and theft from motor vehicles demonstrated slightly negative correlations, suggesting that unemployment alone does not strongly drive crime rates. This analysis is valuable because it highlights the complexity of social behavior - crime trends cannot be explained by a single factor like employment status. Instead, the findings underscore the importance of considering additional influences such as demographics, enforcement policies, and community conditions when developing strategies to reduce crime.

# %% [markdown]
# ## Section 6: Conclusion

# %% [markdown]
# Overall, our analysis revealed meaningful patterns across both crime and employment data in Los Angeles. Crime rates showed clear variations by time, type, and victim demographics, while unemployment followed a distinct seasonal trend with steady improvement since 2021. However, when comparing the two datasets, we found only limited correlation between crime and employment patterns. This suggests that while both factors independently shape community well being, their relationship is likely influenced by additional social and economic variables beyond the scope of this study.

# %% [markdown]
# ### 6.1 Challenges
#
# Throughout this project, our team encountered several challenges related to data cleaning, formatting, and integration. The crime dataset required extensive preprocessing due to inconsistent date formats, missing victim information, and variations in categorical values. We had to manually reformat and standardize these entries to ensure the data could be analyzed consistently. The employment dataset also posed difficulties, as it only provided monthly data, making it difficult to align precisely with the daily crime records. Additionally, merging and comparing two large datasets from different sources required multiple iterations of verification and restructuring to maintain accuracy. Despite these challenges, careful reorganization and validation allowed us to conduct a meaningful analysis of crime and employment trends in Los Angeles.

# %% [markdown]
# ### 6.2 Risks and Limitations

# %% [markdown]
# Our analysis comes with several limitations that affect how confidently the results can be interpreted. One major challenge was the quality and consistency of the data. The crime dataset contained missing or incorrect information, particularly in the victim sex variable, as well as inconsistent date formatting that required manual reorganization. Similarly, the employment dataset only provided monthly data, which made it difficult to align precisely with daily or weekly crime trends. These inconsistencies limited the depth of our comparisons and reduced the strength of any statistical relationship we could establish between employment and crime rates.
#
# Additionally, the two datasets showed minimal correlation, suggesting that other external factors such as demographic changes, law enforcement policies, or broader economic shifts may be influencing the patterns we observed. While our findings provide useful insights, they remain correlational rather than causal. Because the data itself is flawed, any analysis or visualization built on it may reflect those inaccuracies. Misleading trends, proportion errors, or unintentional bias could appear if certain groups or incidents were underreported or misclassified.
#
# From an analytical standpoint, this project also faced general EDA related risks, including data dependency and visualization bias. The accuracy of exploratory analysis depends heavily on the quality of the source data; when that data contains errors or gaps, the resulting visuals may unintentionally exaggerate or downplay certain patterns. Moreover, integrating multiple datasets from different sources introduces complexity and potential inconsistencies that can skew interpretations. As a result, while this project highlights meaningful trends, it cannot provide complete clarity or predictive accuracy. Future research could benefit from more standardized, high resolution datasets and stronger validation processes to minimize bias and ensure greater reliability.

# %% [markdown]
# ### 6.3 Recommendations

# %% [markdown]
# Although our analysis found limited correlation between employment trends and crime rates, the data still offers meaningful insights that can guide local action. Rather than relying on a direct causal link, these recommendations focus on practical, community centered strategies that promote safety and stability in Los Angeles.
#
# 1. **Targeted Prevention Efforts:** Increase law enforcement visibility during high-activity periods, such as around noon, particularly in areas like Central and Southwest. Even without strong correlation, these areas consistently show elevated crime levels where increased presence could help deter incidents.
#
# 2. **Community Education and Support:** Expand community programs centered on violence prevention, conflict resolution, and self protection. Efforts should especially focus on intimate partner violence, deadly weapon related assaults, and shoplifting where gender specific risks remain significant.
#
# 3. **Employment and Workforce Initiatives:** Continue supporting temporary work programs, job fairs, and workforce training particularly during the summer months when unemployment tends to rise. While employment alone may not drive crime rates, strengthening economic opportunity can indirectly support long-term stability.
#
# 4. **Improved Data Practices:** Future research and policymaking should prioritize more accurate and consistent data collection, particularly in areas like victim demographics and employment details, to enable clearer insights and evidence based strategies.
#
# Overall, these recommendations highlight the value of combining law enforcement, community engagement, and workforce initiatives to build safer, more resilient neighborhoods, even when data relationships remain complex or uncertain.

# %% [markdown]
# ## Section 7: AI Disclosure Statement

# %% [markdown]
# ### 7.1 AI Appendix
#
# In completing this project, we used generative AI tools to support the development, organization, and presentation of our work.
#
# 1. **Coding Support & Debugging:** ChatGPT was used to provide quick syntax guidance, troubleshoot errors, and improve the efficiency of our Python code. It also assisted in refining complex data cleaning routines applied to both the crime and employment datasets.
#
# 2. **Analysis Framing & Visualization:** AI tools were used to help brainstorm analysis framing, clarify data interpretation, and explore visualization options for presenting results.
#
# 3. **Writing & Documentation:** ChatGPT assisted in summarizing findings, editing written sections for clarity, and streamlining comments and docstrings.
#
# All AI-generated content was carefully reviewed, edited, and verified by our team to ensure accuracy, originality, and compliance with academic integrity standards.

# %% [markdown]
# ### 7.2 References
#
# 1. City’s Danger Zone : In the 77th, It’s Life at Mach 2 https://www.latimes.com/archives/la-xpm-1989-05-14-mn-412-story.html
# 2. Change in LAPD data collections: https://www.lapdonline.org/newsroom/lapd-reinstates-public-crime-data-on-www-lapdonline-org-nr24247ma/
# 3. Decrease in violent crimes in 2024: https://abc7.com/post/los-angeles-saw-decrease-violent-crimes-2024-mayor-karen-bass-lapd-chief-jim-mcdonnell-say/16038738/
# 4. Crime Trends in US Cities: https://counciloncj.org/crime-trends-in-u-s-cities-mid-year-2025-update/
